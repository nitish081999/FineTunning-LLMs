# %% [markdown]
# # Merge algorithms

# %% [markdown]
# ## 1. SLERP

# %% [markdown]
# **Spherical Linear Interpolation** (SLERP) is a method used to smoothly interpolate between two vectors. It maintains a constant rate of change and preserves the geometric properties of the spherical space in which the vectors reside.

# %% [markdown]
# There are several reasons to prefer SLERP over a traditional linear interpolation. For example, in high-dimensional spaces, linear interpolation can lead to a decrease in the magnitude of the interpolated vector (i.e., it reduces the scale of weights). Moreover, the change in direction of the weights often represents more meaningful information (like feature learning and representation) than the magnitude of change.
#
# SLERP is implemented using the following steps:
#
# Normalize the input vectors to unit length, ensuring they represent directions rather than magnitudes
# Calculate the angle between these vectors using their dot product.
# If the vectors are nearly collinear, it defaults to linear interpolation for efficiency. Otherwise, SLERP computing scale factors based on the interpolation factor t (t=0 = 100% of the first vector, t=1 = 100% of model 2) and the angle between the vectors.
# These factors are used to weigh the original vectors, which are then summed to obtain the interpolated vector.
# SLERP is currently the most popular merging method, but it is limited to combining only two models at a time. It is still possible to hierarchically combine multiple models,

# %% [raw]
# slices:
#   - sources:
#       - model: OpenPipe/mistral-ft-optimized-1218
#         layer_range: [0, 32]
#       - model: mlabonne/NeuralHermes-2.5-Mistral-7B
#         layer_range: [0, 32]
# merge_method: slerp
# base_model: OpenPipe/mistral-ft-optimized-1218
# parameters:
#   t:
#     - filter: self_attn
#       value: [0, 0.5, 0.3, 0.7, 1]
#     - filter: mlp
#       value: [1, 0.5, 0.7, 0.3, 0]
#     - value: 0.5
# dtype: bfloat16

# %% [markdown]
# ## 2. TIES

# %% [markdown]
# Introduced in this paper by Yadav et al., TIES-Merging is designed to efficiently merge multiple task-specific models into a single multitask model. It addresses two main challenges in model merging:
#
# Redundancy in model parameters: It identifies and eliminates redundant parameters within task-specific models. This is achieved by focusing on the changes made during fine-tuning, identifying the top-k% most significant changes, and discarding the rest.
# Disagreement between parameter signs: Conflicts arise when different models suggest opposing adjustments to the same parameter. TIES-Merging resolves these conflicts by creating a unified sign vector that represents the most dominant direction of change across all models.
# TIES-Merging is divided into the following three steps:
#
# Trim: Reduces redundancy in task-specific models by retaining only a fraction the most significant parameters (density parameter) and resetting the rest to zero.
# Elect Sign: Resolves sign conflicts across different models by creating a unified sign vector based on the most dominant direction (positive or negative) in terms of cumulative magnitude.
# Disjoint Merge: Averages parameter values that align with the unified sign vector, excluding zero values.
# Unlike SLERP, TIES can merge multiple models at a time.

# %% [raw]
# models:
#   - model: mistralai/Mistral-7B-v0.1
#     # no parameters necessary for base model
#   - model: OpenPipe/mistral-ft-optimized-1218
#     parameters:
#       density: 0.5
#       weight: 0.5
#   - model: mlabonne/NeuralHermes-2.5-Mistral-7B
#     parameters:
#       density: 0.5
#       weight: 0.3
# merge_method: ties
# base_model: mistralai/Mistral-7B-v0.1
# parameters:
#   normalize: true
# dtype: float16

# %% [markdown]
# With this config, we use Mistral-7B as a base model to calculate the delta weights. We merge the same two models: mistral-ft-optimized-1218 (50%) and NeuralHermes-2.5-Mistral-7B (30%) with normalization. Here, the density means that we’re only retaining 50% of the parameters of each model (the other half comes from the base model).
#
# Note that the sum of the weights is not equal to 1 in the config, but the normalize: true parameter will automatically normalize them internally. This config is inspired by the parameters provided by the author of OpenHermes-2.5-neural-chat-7b-v3-1-7B.
#
# You can find the final model on the Hugging Face Hub at mlabonne/NeuralPipe-7B-ties.

# %% [markdown]
# ## 3. DARE

# %% [markdown]
# Introduced by Yu et al. (2023), DARE uses an approach similar to TIES with two main differences:
#
# Pruning: DARE randomly reset fine-tuned weights to their original values (those of the base model).
# Rescaling: DARE rescales the weights to keep the expectations of model outputs approximately unchanged. It adds the rescaled weights of both (or more) models to the weights of the base model with a scale factor.
# Mergekit’s implementation of this method has two flavours: with the sign election step of TIES (dare_ties) or without (dare_linear).

# %% [raw]
# models:
#   - model: mistralai/Mistral-7B-v0.1
#     # No parameters necessary for base model
#   - model: samir-fama/SamirGPT-v1
#     parameters:
#       density: 0.53
#       weight: 0.4
#   - model: abacusai/Slerp-CM-mist-dpo
#     parameters:
#       density: 0.53
#       weight: 0.3
#   - model: EmbeddedLLM/Mistral-7B-Merge-14-v0.2
#     parameters:
#       density: 0.53
#       weight: 0.3
# merge_method: dare_ties
# base_model: mistralai/Mistral-7B-v0.1
# parameters:
#   int8_mask: true
# dtype: bfloat16

# %% [markdown]
# In this configuration, we merge three different models based on Mistral-7B using dare_ties. This time, I chose weights that sum to 1 (the sum should be between 0.9 and 1.1). The density parameter is a little higher than what’s recommended in the paper (<0.5), but it looks like it gives consistently better results (see this discussion).
#
# You can find it on the Hugging Face Hub at mlabonne/Daredevil-7B. It’s also the best merge model in this article, outperforming even Marcoro14-7B-slerp.

# %% [markdown]
# ## 4. Passthrough

# %% [markdown]
# The passthrough method differs significantly from the previous ones. By concatenating layers from different LLMs, it can produce models with an exotic number of parameters (e.g., 9B with two 7B parameter models). These models are often referred to as “frankenmerges” or “Frankenstein models” by the community.
#
# This technique is very experimental, but it managed to create impressive models, like goliath-120b using two Llama 2 70B models. The recently released SOLAR-10.7B-v1.0 also uses the same idea, called depth-up scaling in their paper.

# %% [raw]
# slices:
#   - sources:
#     - model: OpenPipe/mistral-ft-optimized-1218
#       layer_range: [0, 32]
#   - sources:
#     - model: mlabonne/NeuralHermes-2.5-Mistral-7B
#       layer_range: [24, 32]
# merge_method: passthrough
# dtype: bfloat16

# %% [markdown]
# The resulting frankenmerge will have all the 32 layers from the first model and 8 additional layers from the second model. This creates a frankenmerge with a total of 40 layers and 8.99B parameters. This config is inspired by GML-Mistral-merged-v1.
#
# You can find the final model on the Hugging Face Hub at mlabonne/NeuralPipe-9B-merged.

# %%
# !git clone https://github.com/cg123/mergekit.git
# !cd mergekit && pip install -q -e .
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 2157, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 2157 (delta 316), reused 377 (delta 262), pack-reused 1685
# Receiving objects: 100% (2157/2157), 670.45 KiB | 944.00 KiB/s, done.
# Resolving deltas: 100% (1458/1458), done.

# %%
import yaml

MODEL_NAME = "Marcoro14-7B-slerp"
yaml_config = """
models:
  - model: mistralai/Mistral-7B-v0.1
  - model: samir-fama/SamirGPT-v1
    parameters:
      density: 0.53
      weight: 0.4
  - model: abacusai/Slerp-CM-mist-dpo
    parameters:
      density: 0.53
      weight: 0.3
  - model: EmbeddedLLM/Mistral-7B-Merge-14-v0.2
    parameters:
      density: 0.53
      weight: 0.3
merge_method: dare_ties
base_model: mistralai/Mistral-7B-v0.1
parameters:
  int8_mask: true
dtype: bfloat16
"""

# Save config as yaml file
with open('config.yaml', 'w', encoding="utf-8") as f:
    f.write(yaml_config)

# %% [markdown]
# We run the merge command with the following parameters:
#
# --copy-tokenizer to copy the tokenizer from the base model
# --allow-crimes and --out-shard-size to chunk the models into smaller shards that can be computed on a CPU with low RAM
# --lazy-unpickle to enable the experimental lazy unpickler for lower memory usage
# In addition, some models can require the --trust_remote_code flag (this is not the case with Mistral-7B).
#
# This command will download the weights of all the models listed in the merge configuration and run the selected merge method (it should take ~10 minutes).

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mergekit-yaml config.yaml merge --copy-tokenizer --allow-crimes --out-shard-size 1B --lazy-unpickle
# Out:
# config.json: 100%|█████████████████████████████| 648/648 [00:00<00:00, 1.92MB/s]
# config.json: 100%|█████████████████████████████| 571/571 [00:00<00:00, 1.60MB/s]
# config.json: 100%|█████████████████████████████| 652/652 [00:00<00:00, 2.08MB/s]
# Warmup loader cache:   0%|                                | 0/4 [00:00<?, ?it/s]
# Fetching 8 files:   0%|                                   | 0/8 [00:00<?, ?it/s]
#
# tokenizer.json:   0%|                               | 0.00/1.80M [00:00<?, ?B/s]
#
#
# tokenizer_config.json: 100%|███████████████| 1.06k/1.06k [00:00<00:00, 3.43MB/s]
#
#
#
# tokenizer.model:   0%|                               | 0.00/493k [00:00<?, ?B/s]
#
#
#
# model-00002-of-00002.safetensors:   0%|             | 0.00/4.51G [00:00<?, ?B/s]
#
#
#
#
# special_tokens_map.json: 100%|█████████████████| 487/487 [00:00<00:00, 3.81MB/s]
#
#
#
#
#
# model.safetensors.index.json: 100%|████████| 22.8k/22.8k [00:00<00:00, 85.5MB/s]
#
#
#
#
#
# model-00001-of-00002.safetensors:   0%|             | 0.00/9.98G [00:00<?, ?B/s]
#
# tokenizer.json: 100%|███████████████████████| 1.80M/1.80M [00:02<00:00, 757kB/s]
#
#
#
# tokenizer.model: 100%|████████████████████████| 493k/493k [00:01<00:00, 283kB/s]
#
#
#
#
# model-00002-of-00002.safetensors:   0%|   | 10.5M/4.51G [00:19<2:21:29, 530kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 10.5M/9.98G [00:26<6:56:33, 399kB/s]
#
#
#
# model-00002-of-00002.safetensors:   0%|   | 10.5M/4.51G [00:34<2:21:29, 530kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 10.5M/9.98G [00:36<6:56:33, 399kB/s]
#
#
#
# model-00002-of-00002.safetensors:   0%|   | 21.0M/4.51G [00:44<2:43:45, 457kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 21.0M/9.98G [00:52<6:51:09, 404kB/s]
#
#
#
# model-00002-of-00002.safetensors:   0%|   | 21.0M/4.51G [00:57<2:43:45, 457kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 21.0M/9.98G [01:04<6:51:09, 404kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 31.5M/4.51G [01:05<2:36:35, 476kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 31.5M/9.98G [01:15<6:31:32, 423kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 31.5M/4.51G [01:17<2:36:35, 476kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 41.9M/4.51G [01:24<2:26:44, 507kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 31.5M/9.98G [01:26<6:31:32, 423kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 41.9M/4.51G [01:34<2:26:44, 507kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 41.9M/9.98G [01:40<6:36:01, 418kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 52.4M/4.51G [01:44<2:24:02, 515kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   0%|   | 41.9M/9.98G [01:54<6:36:01, 418kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 52.4M/4.51G [01:54<2:24:02, 515kB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|   | 62.9M/4.51G [02:02<2:17:40, 538kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|   | 52.4M/9.98G [02:04<6:28:07, 426kB/s]
#
#
#
# model-00002-of-00002.safetensors:   2%|   | 73.4M/4.51G [02:07<1:46:04, 697kB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|   | 62.9M/9.98G [02:08<4:38:03, 594kB/s]
#
#
#
# model-00002-of-00002.safetensors:   2%|   | 83.9M/4.51G [02:09<1:14:42, 987kB/s]
#
#
#
# model-00002-of-00002.safetensors:   2%|    | 94.4M/4.51G [02:09<52:35, 1.40MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|   | 73.4M/9.98G [02:09<3:12:50, 856kB/s]
#
#
#
# model-00002-of-00002.safetensors:   2%|     | 105M/4.51G [02:10<37:18, 1.97MB/s]
#
#
#
# model-00002-of-00002.safetensors:   3%|▏    | 115M/4.51G [02:10<26:56, 2.72MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|  | 83.9M/9.98G [02:10<2:15:18, 1.22MB/s]
#
#
#
# model-00002-of-00002.safetensors:   3%|▏    | 126M/4.51G [02:11<19:45, 3.70MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|  | 94.4M/9.98G [02:11<1:36:15, 1.71MB/s]
#
#
#
# model-00002-of-00002.safetensors:   3%|▏    | 136M/4.51G [02:11<14:49, 4.92MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|   | 105M/9.98G [02:12<1:10:00, 2.35MB/s]
#
#
#
# model-00002-of-00002.safetensors:   3%|▏    | 147M/4.51G [02:12<11:40, 6.23MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 115M/9.98G [02:12<51:33, 3.19MB/s]
#
#
#
# model-00002-of-00002.safetensors:   3%|▏    | 157M/4.51G [02:13<09:20, 7.77MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 126M/9.98G [02:13<38:34, 4.26MB/s]
#
#
#
# model-00002-of-00002.safetensors:   4%|▏    | 168M/4.51G [02:13<07:36, 9.50MB/s]
#
#
#
# model-00002-of-00002.safetensors:   4%|▏    | 178M/4.51G [02:14<06:24, 11.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 136M/9.98G [02:13<29:37, 5.54MB/s]
#
#
#
# model-00002-of-00002.safetensors:   4%|▏    | 189M/4.51G [02:14<05:37, 12.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 147M/9.98G [02:14<23:21, 7.02MB/s]
#
#
#
# model-00002-of-00002.safetensors:   4%|▏    | 199M/4.51G [02:15<04:54, 14.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 157M/9.98G [02:15<18:42, 8.75MB/s]
#
#
#
# model-00002-of-00002.safetensors:   5%|▏    | 210M/4.51G [02:15<04:25, 16.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 168M/9.98G [02:15<15:54, 10.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:   5%|▏    | 220M/4.51G [02:16<04:54, 14.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 178M/9.98G [02:16<15:27, 10.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:   5%|▎    | 231M/4.51G [02:17<04:30, 15.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 189M/9.98G [02:17<13:34, 12.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:   5%|▎    | 241M/4.51G [02:17<04:15, 16.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 199M/9.98G [02:17<12:07, 13.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:   6%|▎    | 252M/4.51G [02:18<03:59, 17.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 210M/9.98G [02:18<11:13, 14.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:   6%|▎    | 262M/4.51G [02:18<03:54, 18.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 220M/9.98G [02:18<10:10, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:   6%|▎    | 273M/4.51G [02:19<03:39, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 231M/9.98G [02:19<09:26, 17.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:   6%|▎    | 283M/4.51G [02:19<03:32, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   2%|     | 241M/9.98G [02:19<08:49, 18.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:   7%|▎    | 294M/4.51G [02:20<03:30, 20.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 252M/9.98G [02:20<08:39, 18.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:   7%|▎    | 304M/4.51G [02:20<03:20, 20.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 262M/9.98G [02:20<08:04, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:   7%|▎    | 315M/4.51G [02:20<03:11, 21.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 273M/9.98G [02:21<07:51, 20.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:   7%|▎    | 325M/4.51G [02:21<03:08, 22.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 283M/9.98G [02:21<07:40, 21.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:   7%|▎    | 336M/4.51G [02:21<03:08, 22.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:   8%|▍    | 346M/4.51G [02:22<03:05, 22.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 294M/9.98G [02:22<07:33, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 304M/9.98G [02:22<07:27, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:   8%|▍    | 357M/4.51G [02:22<03:07, 22.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:   8%|▍    | 367M/4.51G [02:23<03:13, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 315M/9.98G [02:23<07:49, 20.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:   8%|▍    | 377M/4.51G [02:23<03:09, 21.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 325M/9.98G [02:23<07:36, 21.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:   9%|▍    | 388M/4.51G [02:24<03:03, 22.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 336M/9.98G [02:24<07:22, 21.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:   9%|▍    | 398M/4.51G [02:24<02:58, 23.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 346M/9.98G [02:24<07:09, 22.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:   9%|▍    | 409M/4.51G [02:25<03:03, 22.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 357M/9.98G [02:25<07:14, 22.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:   9%|▍    | 419M/4.51G [02:25<03:20, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 367M/9.98G [02:25<08:12, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  10%|▍    | 430M/4.51G [02:26<03:24, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 377M/9.98G [02:26<08:22, 19.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  10%|▍    | 440M/4.51G [02:26<03:25, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 388M/9.98G [02:26<08:07, 19.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  10%|▌    | 451M/4.51G [02:27<03:39, 18.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 398M/9.98G [02:27<08:28, 18.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  10%|▌    | 461M/4.51G [02:28<03:32, 19.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 409M/9.98G [02:27<08:10, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  10%|▌    | 472M/4.51G [02:28<03:33, 18.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 419M/9.98G [02:28<08:15, 19.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  11%|▌    | 482M/4.51G [02:29<03:26, 19.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 430M/9.98G [02:29<08:06, 19.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  11%|▌    | 493M/4.51G [02:29<03:30, 19.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 440M/9.98G [02:29<08:25, 18.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  11%|▌    | 503M/4.51G [02:30<03:35, 18.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 451M/9.98G [02:30<10:19, 15.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  11%|▌    | 514M/4.51G [02:30<03:33, 18.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 461M/9.98G [02:31<09:58, 15.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  12%|▌    | 524M/4.51G [02:31<03:25, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 472M/9.98G [02:31<09:23, 16.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  12%|▌    | 535M/4.51G [02:32<03:47, 17.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 482M/9.98G [02:32<08:55, 17.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  12%|▌    | 545M/4.51G [02:32<03:33, 18.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 493M/9.98G [02:32<09:08, 17.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  12%|▌    | 556M/4.51G [02:33<03:57, 16.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 503M/9.98G [02:33<09:07, 17.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  13%|▋    | 566M/4.51G [02:33<03:46, 17.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 514M/9.98G [02:34<08:39, 18.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  13%|▋    | 577M/4.51G [02:34<03:26, 19.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 524M/9.98G [02:34<08:01, 19.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  13%|▋    | 587M/4.51G [02:34<03:12, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 535M/9.98G [02:34<07:28, 21.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  13%|▋    | 598M/4.51G [02:35<03:02, 21.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 545M/9.98G [02:35<07:21, 21.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  13%|▋    | 608M/4.51G [02:35<02:59, 21.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 556M/9.98G [02:35<07:15, 21.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  14%|▋    | 619M/4.51G [02:36<02:53, 22.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 566M/9.98G [02:36<07:11, 21.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  14%|▋    | 629M/4.51G [02:36<02:51, 22.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 577M/9.98G [02:36<07:16, 21.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  14%|▋    | 640M/4.51G [02:37<02:55, 22.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 587M/9.98G [02:37<07:18, 21.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  14%|▋    | 650M/4.51G [02:37<02:51, 22.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 598M/9.98G [02:37<07:16, 21.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  15%|▋    | 661M/4.51G [02:37<02:52, 22.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 608M/9.98G [02:38<07:22, 21.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  15%|▋    | 671M/4.51G [02:38<02:52, 22.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 619M/9.98G [02:38<07:10, 21.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  15%|▊    | 682M/4.51G [02:38<02:48, 22.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 629M/9.98G [02:39<07:12, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  15%|▊    | 692M/4.51G [02:39<02:52, 22.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   6%|▎    | 640M/9.98G [02:39<07:25, 21.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  16%|▊    | 703M/4.51G [02:39<02:56, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  16%|▊    | 713M/4.51G [02:40<03:04, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 650M/9.98G [02:40<07:46, 20.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  16%|▊    | 724M/4.51G [02:40<03:05, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 661M/9.98G [02:40<07:44, 20.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  16%|▊    | 734M/4.51G [02:41<03:04, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 671M/9.98G [02:41<07:50, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  17%|▊    | 744M/4.51G [02:42<03:14, 19.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 682M/9.98G [02:42<09:40, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  17%|▊    | 755M/4.51G [02:42<03:04, 20.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 692M/9.98G [02:43<09:37, 16.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  17%|▊    | 765M/4.51G [02:43<03:17, 19.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 703M/9.98G [02:43<09:10, 16.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  17%|▊    | 776M/4.51G [02:43<03:15, 19.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 713M/9.98G [02:44<08:35, 18.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  17%|▊    | 786M/4.51G [02:44<03:07, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 724M/9.98G [02:44<08:11, 18.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  18%|▉    | 797M/4.51G [02:44<03:03, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 734M/9.98G [02:45<07:55, 19.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  18%|▉    | 807M/4.51G [02:45<02:59, 20.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 744M/9.98G [02:45<07:44, 19.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  18%|▉    | 818M/4.51G [02:45<02:59, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 755M/9.98G [02:46<07:31, 20.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  18%|▉    | 828M/4.51G [02:46<02:54, 21.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 765M/9.98G [02:46<07:23, 20.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  19%|▉    | 839M/4.51G [02:46<02:50, 21.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  19%|▉    | 849M/4.51G [02:47<02:47, 21.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 776M/9.98G [02:47<07:22, 20.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  19%|▉    | 860M/4.51G [02:50<07:51, 7.74MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 786M/9.98G [02:51<26:35, 5.76MB/s]
#
#
#
# model-00002-of-00002.safetensors:  19%|▉    | 870M/4.51G [02:53<10:38, 5.70MB/s]
#
#
#
# model-00002-of-00002.safetensors:  20%|▉    | 881M/4.51G [02:54<09:12, 6.56MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 797M/9.98G [02:54<29:47, 5.14MB/s]
#
#
#
# model-00002-of-00002.safetensors:  20%|▉    | 891M/4.51G [02:55<07:32, 7.99MB/s]
#
#
#
# model-00002-of-00002.safetensors:  20%|█    | 902M/4.51G [02:55<06:18, 9.53MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 807M/9.98G [02:55<26:08, 5.84MB/s]
#
#
#
# model-00002-of-00002.safetensors:  20%|█    | 912M/4.51G [02:56<05:10, 11.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  20%|█    | 923M/4.51G [02:56<04:24, 13.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 818M/9.98G [02:56<22:11, 6.88MB/s]
#
#
#
# model-00002-of-00002.safetensors:  21%|█    | 933M/4.51G [02:57<03:47, 15.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 828M/9.98G [02:57<18:32, 8.23MB/s]
#
#
#
# model-00002-of-00002.safetensors:  21%|█    | 944M/4.51G [02:57<03:20, 17.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   8%|▍    | 839M/9.98G [02:57<15:38, 9.73MB/s]
#
#
#
# model-00002-of-00002.safetensors:  21%|█    | 954M/4.51G [02:58<03:14, 18.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  21%|█    | 965M/4.51G [02:58<03:09, 18.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 849M/9.98G [02:58<13:27, 11.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  22%|█    | 975M/4.51G [02:59<02:57, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 860M/9.98G [02:58<11:25, 13.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  22%|█    | 986M/4.51G [02:59<02:57, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 870M/9.98G [02:59<10:25, 14.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 881M/9.98G [02:59<09:28, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  22%|█    | 996M/4.51G [03:00<03:24, 17.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 891M/9.98G [03:00<08:34, 17.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  22%|▉   | 1.01G/4.51G [03:00<03:11, 18.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 902M/9.98G [03:00<08:20, 18.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  23%|▉   | 1.02G/4.51G [03:01<03:06, 18.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 912M/9.98G [03:01<08:11, 18.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  23%|▉   | 1.03G/4.51G [03:01<03:06, 18.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 923M/9.98G [03:02<08:01, 18.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  23%|▉   | 1.04G/4.51G [03:02<02:55, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 933M/9.98G [03:02<08:00, 18.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  23%|▉   | 1.05G/4.51G [03:02<02:54, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  23%|▉   | 1.06G/4.51G [03:03<02:42, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:   9%|▍    | 944M/9.98G [03:03<09:02, 16.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  24%|▉   | 1.07G/4.51G [03:03<02:35, 22.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍    | 954M/9.98G [03:03<08:34, 17.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  24%|▉   | 1.08G/4.51G [03:04<02:46, 20.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍    | 965M/9.98G [03:04<08:28, 17.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  24%|▉   | 1.09G/4.51G [03:04<02:41, 21.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍    | 975M/9.98G [03:05<08:02, 18.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  24%|▉   | 1.10G/4.51G [03:05<02:35, 21.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍    | 986M/9.98G [03:05<07:36, 19.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  25%|▉   | 1.11G/4.51G [03:05<02:31, 22.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍    | 996M/9.98G [03:05<07:33, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  25%|▉   | 1.12G/4.51G [03:06<02:27, 22.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  25%|█   | 1.13G/4.51G [03:06<02:25, 23.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍   | 1.01G/9.98G [03:06<07:22, 20.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  25%|█   | 1.14G/4.51G [03:07<02:24, 23.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍   | 1.02G/9.98G [03:06<07:15, 20.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  26%|█   | 1.15G/4.51G [03:07<02:22, 23.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍   | 1.03G/9.98G [03:07<07:07, 20.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  26%|█   | 1.16G/4.51G [03:07<02:27, 22.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  10%|▍   | 1.04G/9.98G [03:08<07:24, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  26%|█   | 1.17G/4.51G [03:08<02:44, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.05G/9.98G [03:08<07:36, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  26%|█   | 1.18G/4.51G [03:09<02:43, 20.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.06G/9.98G [03:09<07:42, 19.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  27%|█   | 1.20G/4.51G [03:09<02:40, 20.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.07G/9.98G [03:09<07:27, 19.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  27%|█   | 1.21G/4.51G [03:10<02:39, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.08G/9.98G [03:10<07:32, 19.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  27%|█   | 1.22G/4.51G [03:10<02:41, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.09G/9.98G [03:10<07:27, 19.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  27%|█   | 1.23G/4.51G [03:11<02:38, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.10G/9.98G [03:11<07:16, 20.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  27%|█   | 1.24G/4.51G [03:11<02:34, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.11G/9.98G [03:11<07:12, 20.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  28%|█   | 1.25G/4.51G [03:12<02:30, 21.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.12G/9.98G [03:12<07:13, 20.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  28%|█   | 1.26G/4.51G [03:12<02:33, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.13G/9.98G [03:12<07:07, 20.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  28%|█▏  | 1.27G/4.51G [03:13<02:47, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  11%|▍   | 1.14G/9.98G [03:13<07:54, 18.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  28%|█▏  | 1.28G/4.51G [03:13<02:44, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.15G/9.98G [03:13<07:43, 19.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  29%|█▏  | 1.29G/4.51G [03:14<02:40, 20.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.16G/9.98G [03:14<07:18, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  29%|█▏  | 1.30G/4.51G [03:14<02:35, 20.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.17G/9.98G [03:14<07:08, 20.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  29%|█▏  | 1.31G/4.51G [03:15<02:31, 21.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.18G/9.98G [03:15<07:26, 19.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  29%|█▏  | 1.32G/4.51G [03:15<02:41, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.20G/9.98G [03:16<07:32, 19.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  30%|█▏  | 1.33G/4.51G [03:16<02:41, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.21G/9.98G [03:16<07:18, 20.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  30%|█▏  | 1.34G/4.51G [03:16<02:37, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.22G/9.98G [03:17<07:19, 19.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  30%|█▏  | 1.35G/4.51G [03:17<02:39, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.23G/9.98G [03:17<07:14, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  30%|█▏  | 1.36G/4.51G [03:17<02:34, 20.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  12%|▍   | 1.24G/9.98G [03:18<07:08, 20.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  30%|█▏  | 1.37G/4.51G [03:18<02:34, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.25G/9.98G [03:18<07:09, 20.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  31%|█▏  | 1.38G/4.51G [03:18<02:35, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.26G/9.98G [03:19<07:11, 20.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  31%|█▏  | 1.39G/4.51G [03:19<02:31, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.27G/9.98G [03:19<07:13, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  31%|█▏  | 1.41G/4.51G [03:19<02:36, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.28G/9.98G [03:20<07:19, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  31%|█▎  | 1.42G/4.51G [03:20<02:30, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.29G/9.98G [03:20<07:11, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  32%|█▎  | 1.43G/4.51G [03:20<02:25, 21.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.30G/9.98G [03:21<07:25, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  32%|█▎  | 1.44G/4.51G [03:21<02:28, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.31G/9.98G [03:21<07:17, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  32%|█▎  | 1.45G/4.51G [03:21<02:27, 20.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.32G/9.98G [03:22<07:03, 20.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  32%|█▎  | 1.46G/4.51G [03:22<02:21, 21.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.33G/9.98G [03:22<07:02, 20.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  33%|█▎  | 1.47G/4.51G [03:22<02:19, 21.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  33%|█▎  | 1.48G/4.51G [03:23<02:48, 18.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  13%|▌   | 1.34G/9.98G [03:23<08:33, 16.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  33%|█▎  | 1.49G/4.51G [03:24<02:41, 18.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.35G/9.98G [03:24<08:27, 17.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  33%|█▎  | 1.50G/4.51G [03:24<02:36, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.36G/9.98G [03:24<07:52, 18.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  34%|█▎  | 1.51G/4.51G [03:25<02:30, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.37G/9.98G [03:25<07:35, 18.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  34%|█▎  | 1.52G/4.51G [03:25<02:26, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.38G/9.98G [03:25<07:24, 19.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  34%|█▎  | 1.53G/4.51G [03:26<02:26, 20.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.39G/9.98G [03:26<07:19, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  34%|█▎  | 1.54G/4.51G [03:26<02:24, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.41G/9.98G [03:26<07:44, 18.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  34%|█▍  | 1.55G/4.51G [03:27<02:19, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.42G/9.98G [03:27<08:10, 17.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  35%|█▍  | 1.56G/4.51G [03:27<02:23, 20.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  35%|█▍  | 1.57G/4.51G [03:28<02:16, 21.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.43G/9.98G [03:28<08:26, 16.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  35%|█▍  | 1.58G/4.51G [03:28<02:13, 21.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  14%|▌   | 1.44G/9.98G [03:28<08:27, 16.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  35%|█▍  | 1.59G/4.51G [03:29<02:14, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  36%|█▍  | 1.60G/4.51G [03:29<02:10, 22.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.45G/9.98G [03:29<08:26, 16.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  36%|█▍  | 1.61G/4.51G [03:30<02:11, 22.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.46G/9.98G [03:30<09:28, 15.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  36%|█▍  | 1.63G/4.51G [03:30<02:23, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.47G/9.98G [03:30<08:25, 16.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  36%|█▍  | 1.64G/4.51G [03:31<02:14, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.48G/9.98G [03:31<08:04, 17.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  37%|█▍  | 1.65G/4.51G [03:31<02:09, 22.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  37%|█▍  | 1.66G/4.51G [03:31<02:11, 21.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.49G/9.98G [03:31<08:19, 17.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  37%|█▍  | 1.67G/4.51G [03:32<02:13, 21.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.50G/9.98G [03:32<08:30, 16.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  37%|█▍  | 1.68G/4.51G [03:32<02:13, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.51G/9.98G [03:33<08:15, 17.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  37%|█▍  | 1.69G/4.51G [03:33<02:17, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.52G/9.98G [03:33<08:00, 17.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  38%|█▌  | 1.70G/4.51G [03:34<02:40, 17.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.53G/9.98G [03:34<08:16, 17.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  38%|█▌  | 1.71G/4.51G [03:34<02:32, 18.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  15%|▌   | 1.54G/9.98G [03:35<08:18, 16.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  38%|█▌  | 1.72G/4.51G [03:35<02:32, 18.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▌   | 1.55G/9.98G [03:35<08:05, 17.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  38%|█▌  | 1.73G/4.51G [03:35<02:23, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.56G/9.98G [03:36<08:02, 17.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  39%|█▌  | 1.74G/4.51G [03:36<02:18, 20.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  39%|█▌  | 1.75G/4.51G [03:36<02:20, 19.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.57G/9.98G [03:36<08:07, 17.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  39%|█▌  | 1.76G/4.51G [03:37<02:15, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.58G/9.98G [03:37<08:06, 17.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  39%|█▌  | 1.77G/4.51G [03:37<02:07, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.59G/9.98G [03:38<08:28, 16.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  40%|█▌  | 1.78G/4.51G [03:38<02:14, 20.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  40%|█▌  | 1.79G/4.51G [03:39<02:35, 17.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.60G/9.98G [03:39<09:51, 14.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  40%|█▌  | 1.80G/4.51G [03:39<02:24, 18.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.61G/9.98G [03:39<09:14, 15.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  40%|█▌  | 1.81G/4.51G [03:40<02:13, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.63G/9.98G [03:40<08:25, 16.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  40%|█▌  | 1.82G/4.51G [03:40<02:09, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  16%|▋   | 1.64G/9.98G [03:40<08:02, 17.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  41%|█▋  | 1.84G/4.51G [03:41<02:09, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.65G/9.98G [03:41<07:54, 17.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  41%|█▋  | 1.85G/4.51G [03:41<02:20, 18.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.66G/9.98G [03:41<07:40, 18.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  41%|█▋  | 1.86G/4.51G [03:42<02:14, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.67G/9.98G [03:42<07:18, 19.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  41%|█▋  | 1.87G/4.51G [03:42<02:11, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.68G/9.98G [03:43<07:35, 18.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  42%|█▋  | 1.88G/4.51G [03:43<02:24, 18.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.69G/9.98G [03:43<07:31, 18.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  42%|█▋  | 1.89G/4.51G [03:43<02:13, 19.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.70G/9.98G [03:44<07:05, 19.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  42%|█▋  | 1.90G/4.51G [03:44<02:06, 20.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.71G/9.98G [03:44<06:59, 19.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  42%|█▋  | 1.91G/4.51G [03:44<02:07, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.72G/9.98G [03:45<07:11, 19.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  43%|█▋  | 1.92G/4.51G [03:45<02:08, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.73G/9.98G [03:45<06:56, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  43%|█▋  | 1.93G/4.51G [03:45<02:04, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  17%|▋   | 1.74G/9.98G [03:46<06:33, 21.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  43%|█▋  | 1.94G/4.51G [03:46<01:58, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  43%|█▋  | 1.95G/4.51G [03:46<01:51, 23.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.75G/9.98G [03:46<07:49, 17.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  44%|█▋  | 1.96G/4.51G [03:47<02:16, 18.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.76G/9.98G [03:47<08:34, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  44%|█▋  | 1.97G/4.51G [03:47<02:08, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.77G/9.98G [03:48<07:40, 17.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  44%|█▊  | 1.98G/4.51G [03:48<02:01, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.78G/9.98G [03:48<07:04, 19.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  44%|█▊  | 1.99G/4.51G [03:48<02:02, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.79G/9.98G [03:49<06:53, 19.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  44%|█▊  | 2.00G/4.51G [03:49<02:04, 20.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.80G/9.98G [03:49<06:54, 19.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  45%|█▊  | 2.01G/4.51G [03:49<02:01, 20.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.81G/9.98G [03:50<06:26, 21.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  45%|█▊  | 2.02G/4.51G [03:50<01:59, 20.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.82G/9.98G [03:50<06:25, 21.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  45%|█▊  | 2.03G/4.51G [03:50<01:57, 21.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.84G/9.98G [03:50<06:17, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  45%|█▊  | 2.04G/4.51G [03:51<01:53, 21.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  18%|▋   | 1.85G/9.98G [03:51<06:09, 22.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  46%|█▊  | 2.06G/4.51G [03:51<01:53, 21.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▋   | 1.86G/9.98G [03:51<06:19, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▋   | 1.87G/9.98G [03:52<05:55, 22.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  46%|█▊  | 2.07G/4.51G [03:52<02:13, 18.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.88G/9.98G [03:52<05:51, 23.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  46%|█▊  | 2.08G/4.51G [03:53<02:06, 19.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.89G/9.98G [03:53<05:57, 22.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  46%|█▊  | 2.09G/4.51G [03:53<02:00, 20.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.90G/9.98G [03:53<05:55, 22.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  47%|█▊  | 2.10G/4.51G [03:54<01:56, 20.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.91G/9.98G [03:54<05:51, 23.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  47%|█▊  | 2.11G/4.51G [03:54<01:52, 21.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.92G/9.98G [03:54<05:45, 23.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  47%|█▉  | 2.12G/4.51G [03:55<01:49, 21.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.93G/9.98G [03:55<05:47, 23.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  47%|█▉  | 2.13G/4.51G [03:55<01:45, 22.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  19%|▊   | 1.94G/9.98G [03:55<05:46, 23.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  47%|█▉  | 2.14G/4.51G [03:55<01:45, 22.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 1.95G/9.98G [03:56<06:02, 22.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  48%|█▉  | 2.15G/4.51G [03:56<02:00, 19.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 1.96G/9.98G [03:56<07:26, 18.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  48%|█▉  | 2.16G/4.51G [03:57<02:08, 18.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 1.97G/9.98G [03:57<07:24, 18.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  48%|█▉  | 2.17G/4.51G [03:57<02:02, 19.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  48%|█▉  | 2.18G/4.51G [03:58<02:03, 18.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 1.98G/9.98G [03:58<08:38, 15.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  49%|█▉  | 2.19G/4.51G [03:58<01:58, 19.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 1.99G/9.98G [03:58<07:54, 16.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  49%|█▉  | 2.20G/4.51G [03:59<01:53, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 2.00G/9.98G [03:59<07:28, 17.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  49%|█▉  | 2.21G/4.51G [03:59<01:49, 20.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 2.01G/9.98G [03:59<07:00, 18.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  49%|█▉  | 2.22G/4.51G [04:00<01:46, 21.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 2.02G/9.98G [04:00<06:55, 19.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  50%|█▉  | 2.23G/4.51G [04:00<01:53, 20.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 2.03G/9.98G [04:00<07:04, 18.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  50%|█▉  | 2.24G/4.51G [04:01<01:48, 20.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  20%|▊   | 2.04G/9.98G [04:01<06:38, 19.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  50%|██  | 2.25G/4.51G [04:01<01:44, 21.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.06G/9.98G [04:01<06:31, 20.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  50%|██  | 2.26G/4.51G [04:02<01:45, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.07G/9.98G [04:02<06:32, 20.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  50%|██  | 2.28G/4.51G [04:02<01:43, 21.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.08G/9.98G [04:02<06:18, 20.9MB/s]
#
#
#
# model-00002-of-00002.safetensors:  51%|██  | 2.29G/4.51G [04:03<01:44, 21.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.09G/9.98G [04:03<06:05, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  51%|██  | 2.30G/4.51G [04:03<01:41, 21.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.10G/9.98G [04:03<05:53, 22.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  51%|██  | 2.31G/4.51G [04:04<01:37, 22.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.11G/9.98G [04:04<05:42, 23.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  51%|██  | 2.32G/4.51G [04:04<01:35, 22.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.12G/9.98G [04:04<05:30, 23.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  52%|██  | 2.33G/4.51G [04:04<01:32, 23.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.13G/9.98G [04:05<05:44, 22.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  52%|██  | 2.34G/4.51G [04:05<01:38, 21.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  21%|▊   | 2.14G/9.98G [04:05<06:02, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  52%|██  | 2.35G/4.51G [04:05<01:38, 21.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▊   | 2.15G/9.98G [04:06<06:00, 21.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  52%|██  | 2.36G/4.51G [04:06<01:34, 22.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▊   | 2.16G/9.98G [04:06<05:55, 22.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  53%|██  | 2.37G/4.51G [04:06<01:32, 23.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▊   | 2.17G/9.98G [04:07<05:50, 22.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  53%|██  | 2.38G/4.51G [04:07<01:31, 23.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▊   | 2.18G/9.98G [04:07<06:25, 20.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  53%|██  | 2.39G/4.51G [04:07<01:41, 20.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.19G/9.98G [04:08<06:22, 20.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  53%|██▏ | 2.40G/4.51G [04:08<01:39, 21.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.20G/9.98G [04:08<06:04, 21.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  54%|██▏ | 2.41G/4.51G [04:08<01:45, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.21G/9.98G [04:09<05:41, 22.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.22G/9.98G [04:09<05:36, 23.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  54%|██▏ | 2.42G/4.51G [04:09<01:53, 18.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.23G/9.98G [04:09<05:37, 23.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  54%|██▏ | 2.43G/4.51G [04:10<01:54, 18.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  22%|▉   | 2.24G/9.98G [04:10<05:29, 23.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  54%|██▏ | 2.44G/4.51G [04:10<02:01, 17.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.25G/9.98G [04:10<06:00, 21.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  54%|██▏ | 2.45G/4.51G [04:11<01:57, 17.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.26G/9.98G [04:11<06:11, 20.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.28G/9.98G [04:11<05:56, 21.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  55%|██▏ | 2.46G/4.51G [04:12<01:56, 17.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.29G/9.98G [04:12<05:42, 22.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  55%|██▏ | 2.47G/4.51G [04:12<01:56, 17.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.30G/9.98G [04:12<05:28, 23.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  55%|██▏ | 2.49G/4.51G [04:13<01:55, 17.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.31G/9.98G [04:13<05:46, 22.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.32G/9.98G [04:13<05:57, 21.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  55%|██▏ | 2.50G/4.51G [04:13<01:57, 17.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.33G/9.98G [04:14<05:57, 21.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  56%|██▏ | 2.51G/4.51G [04:14<01:50, 18.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  23%|▉   | 2.34G/9.98G [04:14<05:43, 22.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  56%|██▏ | 2.52G/4.51G [04:15<01:51, 17.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.35G/9.98G [04:15<05:27, 23.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  56%|██▏ | 2.53G/4.51G [04:15<01:49, 18.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.36G/9.98G [04:15<05:19, 23.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.37G/9.98G [04:15<05:20, 23.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  56%|██▎ | 2.54G/4.51G [04:16<01:47, 18.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.38G/9.98G [04:16<05:41, 22.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  57%|██▎ | 2.55G/4.51G [04:16<01:45, 18.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.39G/9.98G [04:16<05:32, 22.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  57%|██▎ | 2.56G/4.51G [04:17<01:40, 19.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.40G/9.98G [04:17<05:20, 23.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  57%|██▎ | 2.57G/4.51G [04:17<01:38, 19.7MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.41G/9.98G [04:17<05:12, 24.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  57%|██▎ | 2.58G/4.51G [04:18<01:35, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.42G/9.98G [04:18<05:06, 24.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  57%|██▎ | 2.59G/4.51G [04:18<01:35, 20.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.43G/9.98G [04:18<05:16, 23.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  58%|██▎ | 2.60G/4.51G [04:19<01:29, 21.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  24%|▉   | 2.44G/9.98G [04:19<05:58, 21.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  58%|██▎ | 2.61G/4.51G [04:19<01:25, 22.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  58%|██▎ | 2.62G/4.51G [04:20<01:24, 22.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|▉   | 2.45G/9.98G [04:20<07:18, 17.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  58%|██▎ | 2.63G/4.51G [04:20<01:20, 23.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  59%|██▎ | 2.64G/4.51G [04:20<01:20, 23.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|▉   | 2.46G/9.98G [04:20<07:50, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  59%|██▎ | 2.65G/4.51G [04:21<01:19, 23.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|▉   | 2.47G/9.98G [04:21<08:19, 15.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  59%|██▎ | 2.66G/4.51G [04:21<01:20, 22.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  59%|██▎ | 2.67G/4.51G [04:22<01:26, 21.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|▉   | 2.49G/9.98G [04:22<08:44, 14.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  60%|██▍ | 2.68G/4.51G [04:23<01:38, 18.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|█   | 2.50G/9.98G [04:23<09:00, 13.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  60%|██▍ | 2.69G/4.51G [04:23<01:36, 18.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|█   | 2.51G/9.98G [04:23<08:36, 14.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  60%|██▍ | 2.71G/4.51G [04:24<01:32, 19.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  60%|██▍ | 2.72G/4.51G [04:24<01:30, 19.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|█   | 2.52G/9.98G [04:24<09:02, 13.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  60%|██▍ | 2.73G/4.51G [04:25<01:45, 16.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|█   | 2.53G/9.98G [04:25<10:02, 12.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  25%|█   | 2.54G/9.98G [04:26<09:55, 12.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  61%|██▍ | 2.74G/4.51G [04:26<02:24, 12.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.55G/9.98G [04:27<08:59, 13.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  61%|██▍ | 2.75G/4.51G [04:27<02:14, 13.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.56G/9.98G [04:27<08:45, 14.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  61%|██▍ | 2.76G/4.51G [04:28<02:06, 13.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.57G/9.98G [04:28<08:43, 14.1MB/s]
#
#
#
# model-00002-of-00002.safetensors:  61%|██▍ | 2.77G/4.51G [04:29<02:08, 13.5MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.58G/9.98G [04:29<09:14, 13.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  62%|██▍ | 2.78G/4.51G [04:30<02:31, 11.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.59G/9.98G [04:30<09:11, 13.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  62%|██▍ | 2.79G/4.51G [04:30<02:13, 12.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.60G/9.98G [04:30<08:32, 14.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  62%|██▍ | 2.80G/4.51G [04:31<02:21, 12.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.61G/9.98G [04:31<09:18, 13.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  62%|██▍ | 2.81G/4.51G [04:32<02:02, 13.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.62G/9.98G [04:32<08:22, 14.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  63%|██▌ | 2.82G/4.51G [04:32<01:46, 15.8MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.63G/9.98G [04:32<07:26, 16.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  63%|██▌ | 2.83G/4.51G [04:33<01:33, 18.0MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  26%|█   | 2.64G/9.98G [04:33<07:37, 16.0MB/s]
#
#
#
# model-00002-of-00002.safetensors:  63%|██▌ | 2.84G/4.51G [04:33<01:29, 18.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.65G/9.98G [04:34<07:26, 16.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  63%|██▌ | 2.85G/4.51G [04:34<01:30, 18.3MB/s]
#
#
#
# model-00002-of-00002.safetensors:  64%|██▌ | 2.86G/4.51G [04:34<01:23, 19.6MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.66G/9.98G [04:34<07:31, 16.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  64%|██▌ | 2.87G/4.51G [04:35<01:21, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.67G/9.98G [04:35<07:53, 15.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  64%|██▌ | 2.88G/4.51G [04:35<01:26, 18.8MB/s]
#
#
#
# model-00002-of-00002.safetensors:  64%|██▌ | 2.89G/4.51G [04:36<01:19, 20.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.68G/9.98G [04:36<08:18, 14.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  64%|██▌ | 2.90G/4.51G [04:36<01:22, 19.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.69G/9.98G [04:37<07:58, 15.2MB/s]
#
#
#
# model-00002-of-00002.safetensors:  65%|██▌ | 2.92G/4.51G [04:37<01:22, 19.3MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.71G/9.98G [04:37<07:24, 16.4MB/s]
#
#
#
# model-00002-of-00002.safetensors:  65%|██▌ | 2.93G/4.51G [04:37<01:19, 19.9MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.72G/9.98G [04:38<06:52, 17.6MB/s]
#
#
#
# model-00002-of-00002.safetensors:  65%|██▌ | 2.94G/4.51G [04:38<01:17, 20.2MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.73G/9.98G [04:38<06:49, 17.7MB/s]
#
#
#
# model-00002-of-00002.safetensors:  65%|██▌ | 2.95G/4.51G [04:39<01:26, 18.1MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.74G/9.98G [04:39<07:18, 16.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  66%|██▌ | 2.96G/4.51G [04:39<01:24, 18.4MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  28%|█   | 2.75G/9.98G [04:39<06:53, 17.5MB/s]
#
#
#
# model-00002-of-00002.safetensors:  66%|██▋ | 2.97G/4.51G [04:40<01:18, 19.5MB/s]
#
#
#
#
# ...
#
#
# model-00001-of-00002.safetensors:  39%|█▌  | 3.91G/9.94G [03:44<05:47, 17.4MB/s]
#
#
# model-00001-of-00002.safetensors:  39%|█▌  | 3.92G/9.94G [03:44<05:23, 18.6MB/s]
#
# model-00002-of-00002.safetensors:  85%|███▍| 3.85G/4.54G [03:44<00:43, 15.9MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.93G/9.94G [03:44<05:05, 19.7MB/s]
#
# model-00002-of-00002.safetensors:  85%|███▍| 3.86G/4.54G [03:45<00:40, 16.9MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.94G/9.94G [03:45<05:01, 19.9MB/s]
#
# model-00002-of-00002.safetensors:  85%|███▍| 3.87G/4.54G [03:45<00:38, 17.4MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.95G/9.94G [03:45<04:53, 20.4MB/s]
#
# model-00002-of-00002.safetensors:  85%|███▍| 3.88G/4.54G [03:46<00:36, 18.1MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.96G/9.94G [03:46<04:51, 20.5MB/s]
#
# model-00002-of-00002.safetensors:  86%|███▍| 3.89G/4.54G [03:46<00:34, 19.0MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.97G/9.94G [03:46<04:54, 20.3MB/s]
#
# model-00002-of-00002.safetensors:  86%|███▍| 3.90G/4.54G [03:47<00:33, 19.0MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 3.98G/9.94G [03:47<04:48, 20.7MB/s]
#
# model-00002-of-00002.safetensors:  86%|███▍| 3.91G/4.54G [03:47<00:32, 19.3MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 4.00G/9.94G [03:47<04:46, 20.8MB/s]
#
# model-00002-of-00002.safetensors:  86%|███▍| 3.92G/4.54G [03:48<00:31, 19.5MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 4.01G/9.94G [03:48<04:49, 20.5MB/s]
#
# model-00002-of-00002.safetensors:  87%|███▍| 3.93G/4.54G [03:48<00:30, 19.6MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 4.02G/9.94G [03:49<04:53, 20.2MB/s]
#
# model-00002-of-00002.safetensors:  87%|███▍| 3.94G/4.54G [03:49<00:30, 19.8MB/s]
#
#
# model-00001-of-00002.safetensors:  40%|█▌  | 4.03G/9.94G [03:49<04:56, 20.0MB/s]
#
# model-00002-of-00002.safetensors:  87%|███▍| 3.95G/4.54G [03:49<00:30, 19.6MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▌  | 4.04G/9.94G [03:50<04:56, 19.9MB/s]
#
# model-00002-of-00002.safetensors:  87%|███▍| 3.96G/4.54G [03:50<00:29, 19.7MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.05G/9.94G [03:50<04:54, 20.0MB/s]
#
# model-00002-of-00002.safetensors:  88%|███▌| 3.97G/4.54G [03:50<00:29, 18.9MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.06G/9.94G [03:51<04:59, 19.7MB/s]
#
# model-00002-of-00002.safetensors:  88%|███▌| 3.98G/4.54G [03:51<00:30, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.07G/9.94G [03:51<05:12, 18.8MB/s]
#
# model-00002-of-00002.safetensors:  88%|███▌| 4.00G/4.54G [03:52<00:31, 17.1MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.08G/9.94G [03:52<05:37, 17.4MB/s]
#
# model-00002-of-00002.safetensors:  88%|███▌| 4.01G/4.54G [03:52<00:30, 17.4MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.09G/9.94G [03:53<06:18, 15.5MB/s]
#
# model-00002-of-00002.safetensors:  88%|███▌| 4.02G/4.54G [03:53<00:28, 18.2MB/s]
#
# model-00002-of-00002.safetensors:  89%|███▌| 4.03G/4.54G [03:53<00:28, 18.0MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.10G/9.94G [03:54<06:16, 15.5MB/s]
#
# model-00002-of-00002.safetensors:  89%|███▌| 4.04G/4.54G [03:54<00:27, 18.5MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.11G/9.94G [03:54<06:08, 15.8MB/s]
#
# model-00002-of-00002.safetensors:  89%|███▌| 4.05G/4.54G [03:55<00:26, 19.0MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|█▋  | 4.12G/9.94G [03:55<06:00, 16.1MB/s]
#
# model-00002-of-00002.safetensors:  89%|███▌| 4.06G/4.54G [03:55<00:26, 17.9MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.13G/9.94G [03:55<06:07, 15.8MB/s]
#
# model-00002-of-00002.safetensors:  90%|███▌| 4.07G/4.54G [03:56<00:26, 17.6MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.14G/9.94G [03:56<05:56, 16.3MB/s]
#
# model-00002-of-00002.safetensors:  90%|███▌| 4.08G/4.54G [03:56<00:25, 17.8MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.15G/9.94G [03:57<05:43, 16.9MB/s]
#
# model-00002-of-00002.safetensors:  90%|███▌| 4.09G/4.54G [03:57<00:24, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.16G/9.94G [03:57<05:33, 17.3MB/s]
#
# model-00002-of-00002.safetensors:  90%|███▌| 4.10G/4.54G [03:58<00:24, 18.1MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.17G/9.94G [03:58<05:29, 17.5MB/s]
#
# model-00002-of-00002.safetensors:  91%|███▌| 4.11G/4.54G [03:58<00:24, 17.9MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.18G/9.94G [03:58<05:25, 17.7MB/s]
#
# model-00002-of-00002.safetensors:  91%|███▋| 4.12G/4.54G [03:59<00:23, 18.2MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.19G/9.94G [03:59<05:13, 18.3MB/s]
#
# model-00002-of-00002.safetensors:  91%|███▋| 4.13G/4.54G [03:59<00:22, 18.0MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.20G/9.94G [03:59<05:09, 18.6MB/s]
#
# model-00002-of-00002.safetensors:  91%|███▋| 4.14G/4.54G [04:00<00:21, 18.5MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.22G/9.94G [04:00<05:05, 18.8MB/s]
#
# model-00002-of-00002.safetensors:  91%|███▋| 4.15G/4.54G [04:00<00:20, 19.0MB/s]
#
#
# model-00001-of-00002.safetensors:  42%|█▋  | 4.23G/9.94G [04:00<04:57, 19.2MB/s]
#
# model-00002-of-00002.safetensors:  92%|███▋| 4.16G/4.54G [04:01<00:19, 19.2MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.24G/9.94G [04:01<04:52, 19.5MB/s]
#
# model-00002-of-00002.safetensors:  92%|███▋| 4.17G/4.54G [04:01<00:18, 19.3MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.25G/9.94G [04:02<04:52, 19.5MB/s]
#
# model-00002-of-00002.safetensors:  92%|███▋| 4.18G/4.54G [04:02<00:18, 19.4MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.26G/9.94G [04:02<04:57, 19.1MB/s]
#
# model-00002-of-00002.safetensors:  92%|███▋| 4.19G/4.54G [04:02<00:17, 19.5MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.27G/9.94G [04:03<04:53, 19.4MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.28G/9.94G [04:03<04:43, 20.0MB/s]
#
# model-00002-of-00002.safetensors:  93%|███▋| 4.20G/4.54G [04:03<00:19, 17.1MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.29G/9.94G [04:04<04:35, 20.5MB/s]
#
# model-00002-of-00002.safetensors:  93%|███▋| 4.22G/4.54G [04:04<00:17, 18.2MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.30G/9.94G [04:04<04:36, 20.4MB/s]
#
# model-00002-of-00002.safetensors:  93%|███▋| 4.23G/4.54G [04:04<00:17, 18.0MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.31G/9.94G [04:05<05:03, 18.6MB/s]
#
# model-00002-of-00002.safetensors:  93%|███▋| 4.24G/4.54G [04:05<00:17, 17.6MB/s]
#
#
# model-00001-of-00002.safetensors:  43%|█▋  | 4.32G/9.94G [04:05<05:16, 17.8MB/s]
#
# model-00002-of-00002.safetensors:  94%|███▋| 4.25G/4.54G [04:06<00:16, 17.5MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▋  | 4.33G/9.94G [04:06<05:05, 18.4MB/s]
#
# model-00002-of-00002.safetensors:  94%|███▊| 4.26G/4.54G [04:06<00:16, 17.7MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▋  | 4.34G/9.94G [04:06<04:54, 19.0MB/s]
#
# model-00002-of-00002.safetensors:  94%|███▊| 4.27G/4.54G [04:07<00:15, 18.1MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.35G/9.94G [04:07<05:00, 18.6MB/s]
#
# model-00002-of-00002.safetensors:  94%|███▊| 4.28G/4.54G [04:07<00:14, 18.4MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.36G/9.94G [04:08<04:52, 19.1MB/s]
#
# model-00002-of-00002.safetensors:  94%|███▊| 4.29G/4.54G [04:08<00:13, 18.9MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.37G/9.94G [04:08<04:58, 18.7MB/s]
#
# model-00002-of-00002.safetensors:  95%|███▊| 4.30G/4.54G [04:08<00:12, 18.7MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.38G/9.94G [04:09<05:01, 18.4MB/s]
#
# model-00002-of-00002.safetensors:  95%|███▊| 4.31G/4.54G [04:09<00:12, 18.7MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.39G/9.94G [04:09<05:08, 18.0MB/s]
#
# model-00002-of-00002.safetensors:  95%|███▊| 4.32G/4.54G [04:09<00:12, 18.2MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.40G/9.94G [04:10<05:00, 18.5MB/s]
#
# model-00002-of-00002.safetensors:  95%|███▊| 4.33G/4.54G [04:10<00:11, 18.7MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|█▊  | 4.41G/9.94G [04:10<04:50, 19.0MB/s]
#
# model-00002-of-00002.safetensors:  96%|███▊| 4.34G/4.54G [04:11<00:10, 18.6MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.42G/9.94G [04:11<04:52, 18.9MB/s]
#
# model-00002-of-00002.safetensors:  96%|███▊| 4.35G/4.54G [04:11<00:10, 18.8MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.44G/9.94G [04:12<04:45, 19.3MB/s]
#
# model-00002-of-00002.safetensors:  96%|███▊| 4.36G/4.54G [04:12<00:09, 19.2MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.45G/9.94G [04:12<04:38, 19.7MB/s]
#
# model-00002-of-00002.safetensors:  96%|███▊| 4.37G/4.54G [04:12<00:08, 19.2MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.46G/9.94G [04:13<04:40, 19.6MB/s]
#
# model-00002-of-00002.safetensors:  97%|███▊| 4.38G/4.54G [04:13<00:08, 19.5MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.47G/9.94G [04:13<04:31, 20.2MB/s]
#
# model-00002-of-00002.safetensors:  97%|███▊| 4.39G/4.54G [04:13<00:08, 17.3MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.48G/9.94G [04:14<04:22, 20.8MB/s]
#
# model-00002-of-00002.safetensors:  97%|███▉| 4.40G/4.54G [04:14<00:07, 17.1MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.49G/9.94G [04:14<04:39, 19.5MB/s]
#
# model-00002-of-00002.safetensors:  97%|███▉| 4.41G/4.54G [04:15<00:07, 17.9MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.50G/9.94G [04:15<04:38, 19.5MB/s]
#
# model-00002-of-00002.safetensors:  97%|███▉| 4.42G/4.54G [04:15<00:06, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.51G/9.94G [04:15<04:34, 19.8MB/s]
#
# model-00002-of-00002.safetensors:  98%|███▉| 4.44G/4.54G [04:16<00:05, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  45%|█▊  | 4.52G/9.94G [04:16<04:48, 18.8MB/s]
#
# model-00002-of-00002.safetensors:  98%|███▉| 4.45G/4.54G [04:16<00:05, 18.4MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.53G/9.94G [04:16<04:43, 19.1MB/s]
#
# model-00002-of-00002.safetensors:  98%|███▉| 4.46G/4.54G [04:17<00:04, 19.1MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.54G/9.94G [04:17<04:38, 19.4MB/s]
#
# model-00002-of-00002.safetensors:  98%|███▉| 4.47G/4.54G [04:17<00:03, 19.9MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.55G/9.94G [04:17<04:32, 19.8MB/s]
#
# model-00002-of-00002.safetensors:  99%|███▉| 4.48G/4.54G [04:18<00:03, 20.9MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.56G/9.94G [04:18<05:33, 16.1MB/s]
#
# model-00002-of-00002.safetensors:  99%|███▉| 4.49G/4.54G [04:18<00:02, 19.4MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.57G/9.94G [04:19<05:19, 16.8MB/s]
#
# model-00002-of-00002.safetensors:  99%|███▉| 4.50G/4.54G [04:19<00:02, 19.3MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.58G/9.94G [04:19<05:05, 17.6MB/s]
#
# model-00002-of-00002.safetensors:  99%|███▉| 4.51G/4.54G [04:19<00:01, 19.2MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.59G/9.94G [04:20<05:13, 17.1MB/s]
#
# model-00002-of-00002.safetensors: 100%|███▉| 4.52G/4.54G [04:20<00:01, 18.0MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.60G/9.94G [04:21<04:57, 18.0MB/s]
#
# model-00002-of-00002.safetensors: 100%|███▉| 4.53G/4.54G [04:21<00:00, 18.7MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|█▊  | 4.61G/9.94G [04:21<04:43, 18.8MB/s]
#
# model-00002-of-00002.safetensors: 100%|████| 4.54G/4.54G [04:21<00:00, 17.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|█▊  | 4.62G/9.94G [04:22<04:29, 19.7MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▊  | 4.63G/9.94G [04:22<04:14, 20.8MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▊  | 4.65G/9.94G [04:22<04:00, 22.1MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▊  | 4.66G/9.94G [04:23<03:42, 23.8MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.67G/9.94G [04:23<03:42, 23.7MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.68G/9.94G [04:24<03:29, 25.1MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.69G/9.94G [04:24<03:20, 26.2MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.70G/9.94G [04:24<03:12, 27.2MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.71G/9.94G [04:25<03:10, 27.5MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|█▉  | 4.72G/9.94G [04:25<03:08, 27.8MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.73G/9.94G [04:25<03:06, 27.9MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.74G/9.94G [04:26<03:09, 27.5MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.75G/9.94G [04:26<03:07, 27.8MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.76G/9.94G [04:27<03:06, 27.7MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.77G/9.94G [04:27<03:03, 28.2MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.78G/9.94G [04:27<03:02, 28.3MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.79G/9.94G [04:28<03:10, 27.1MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.80G/9.94G [04:28<03:06, 27.5MB/s]
#
#
# model-00001-of-00002.safetensors:  48%|█▉  | 4.81G/9.94G [04:28<03:02, 28.1MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.82G/9.94G [04:29<03:02, 28.0MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.83G/9.94G [04:29<02:58, 28.6MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.84G/9.94G [04:29<02:56, 28.8MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.85G/9.94G [04:30<02:53, 29.3MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.87G/9.94G [04:30<02:55, 29.0MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.88G/9.94G [04:31<02:55, 28.9MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.89G/9.94G [04:31<02:56, 28.7MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.90G/9.94G [04:31<02:57, 28.4MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.91G/9.94G [04:32<03:01, 27.7MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|█▉  | 4.92G/9.94G [04:32<03:04, 27.2MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|█▉  | 4.93G/9.94G [04:33<03:08, 26.6MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|█▉  | 4.94G/9.94G [04:33<03:06, 26.8MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|█▉  | 4.95G/9.94G [04:33<03:14, 25.7MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|█▉  | 4.96G/9.94G [04:34<03:19, 25.0MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|█▉  | 4.97G/9.94G [04:34<03:26, 24.1MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██  | 4.98G/9.94G [04:35<03:13, 25.6MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██  | 4.99G/9.94G [04:35<03:16, 25.2MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██  | 5.00G/9.94G [04:35<03:09, 26.1MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██  | 5.01G/9.94G [04:36<03:06, 26.5MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.02G/9.94G [04:36<03:06, 26.4MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.03G/9.94G [04:37<03:02, 26.9MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.04G/9.94G [04:37<02:59, 27.4MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.05G/9.94G [04:37<03:04, 26.5MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.06G/9.94G [04:38<03:01, 26.9MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.08G/9.94G [04:38<03:05, 26.2MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.09G/9.94G [04:39<03:09, 25.7MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.10G/9.94G [04:39<03:04, 26.3MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.11G/9.94G [04:39<03:09, 25.5MB/s]
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.12G/9.94G [04:40<03:08, 25.6MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.13G/9.94G [04:40<03:04, 26.1MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.14G/9.94G [04:41<03:00, 26.6MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.15G/9.94G [04:41<02:56, 27.1MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.16G/9.94G [04:41<03:03, 26.0MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.17G/9.94G [04:42<03:03, 26.1MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.18G/9.94G [04:42<03:05, 25.7MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.19G/9.94G [04:43<03:04, 25.8MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.20G/9.94G [04:43<03:04, 25.8MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.21G/9.94G [04:43<03:00, 26.2MB/s]
#
#
# model-00001-of-00002.safetensors:  53%|██  | 5.22G/9.94G [04:44<02:55, 26.9MB/s]

# %% [markdown]
# The model is now merged and saved in the merge directory. Before uploading it, we can create a README file with all the information required for reproducibility. The following code block defines a Jinja template and automatically fills it with the data from the merge configuration.

# %%
# !pip install -qU huggingface_hub

from huggingface_hub import ModelCard, ModelCardData
from jinja2 import Template

username = "mlabonne"

template_text = """
---
license: apache-2.0
tags:
- merge
- mergekit
- lazymergekit
{%- for model in models %}
- {{ model }}
{%- endfor %}
---

# {{ model_name }}

{{ model_name }} is a merge of the following models using [mergekit](https://github.com/cg123/mergekit):

{%- for model in models %}
* [{{ model }}](https://huggingface.co/{{ model }})
{%- endfor %}

## 🧩 Configuration

\```yaml
{{- yaml_config -}}
\```
"""

# Create a Jinja template object
jinja_template = Template(template_text.strip())

# Get list of models from config
data = yaml.safe_load(yaml_config)
if "models" in data:
    models = [data["models"][i]["model"] for i in range(len(data["models"])) if "parameters" in data["models"][i]]
elif "parameters" in data:
    models = [data["slices"][0]["sources"][i]["model"] for i in range(len(data["slices"][0]["sources"]))]
elif "slices" in data:
    models = [data["slices"][i]["sources"][0]["model"] for i in range(len(data["slices"]))]
else:
    raise Exception("No models or slices found in yaml config")

# Fill the template
content = jinja_template.render(
    model_name=MODEL_NAME,
    models=models,
    yaml_config=yaml_config,
    username=username,
)

# Save the model card
card = ModelCard(content)
card.save('merge/README.md')
